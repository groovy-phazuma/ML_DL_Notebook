# %% [markdown]
# ##### Benchmark dataset
# Yahoo Music
# - https://www.kaggle.com/c/ee627A-Spring2019/overview

# %%
BASE_DIR = '/workspace/mnt/cluster/HDD/azuma/Others'

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import sys
sys.path.append(BASE_DIR+'/github/ML_DL_Notebook_Recommendation')
import recomm_utils as ru

# %%
path_dataset = '/workspace/mnt/cluster/HDD/azuma/Others/github/ML_DL_Notebook/_datasource/yahoo_music/training_test_dataset.mat'

u_features, v_features, rating_mx_train, train_labels, u_train_idx, v_train_idx, \
val_labels, u_val_idx, v_val_idx, test_labels, u_test_idx, v_test_idx, class_values = ru.load_data(path_dataset= '/workspace/mnt/cluster/HDD/azuma/Others/github/ML_DL_Notebook/_datasource/yahoo_music/training_test_dataset.mat',seed=1234, verbose=True)
# Out:
# number of unique users =  1357
# number of unique item =  1363
# User features shape: (3000, 3000)
# Item features shape: (3000, 3000)
# Number of users = 3000
# Number of items = 3000
# Number of links = 5335
# Fraction of positive links = 0.0006

# %%
u_features = u_features.todense()
print(u_features.shape)
sns.heatmap(u_features[0:100,0:100])
plt.show()
# Out:
# (3000, 3000)

# %%
v_features = v_features.todense()
print(v_features.shape)
sns.heatmap(v_features[0:100,0:100])
plt.show()
# Out:
# (3000, 3000)

# %%
rating_mx_train = rating_mx_train.todense()
print(rating_mx_train.shape)
sns.heatmap(rating_mx_train[0:100,0:100])
plt.show()
# Out:
# (3000, 3000)

# %%
print(len(train_labels))
print(train_labels)
# Out:
# 3841
# [41 61 26 ... 26 13 13]

# %%
print(len(u_train_idx))
print(u_train_idx)
# Out:
# 3841
# [1601 1930 2851 ... 1821 2247  510]

# %%
print(len(v_train_idx))
print(v_train_idx)
# Out:
# 3841
# [2160  568 2488 ... 1075 1589 1997]

# %%
print(len(class_values))
print(class_values)
# Out:
# 71
# [  1.   4.   6.  10.  11.  13.  16.  17.  19.  20.  23.  25.  28.  30.
#   31.  32.  34.  36.  39.  40.  41.  42.  43.  44.  47.  49.  50.  52.
#   53.  54.  58.  59.  60.  61.  63.  64.  65.  66.  67.  68.  69.  70.
#   71.  72.  73.  74.  75.  76.  77.  78.  79.  80.  81.  82.  83.  84.
#   85.  86.  87.  88.  89.  90.  91.  92.  93.  94.  95.  96.  98.  99.
#  100.]
